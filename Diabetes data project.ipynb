# %%
import scipy as sci
import numpy as np
import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'C:/Users/JOEBO/Desktop/Data Science projects/Diabetes Data/diabetes.csv'
healthdf = pd.read_csv(path)
healthdf.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 1) Number of times pregnant
# 2) Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3) Diastolic blood pressure (mm Hg)
# 4) Triceps skin fold thickness (mm)
# 5) 2-Hour serum insulin (mu U/ml)
# 6) Body mass index (weight in kg/(height in m)^2)
# 7) Diabetes pedigree function
# 8) Age (years)
# 9) Class variable (0 or 1) [1= positive for diabetes]

# %%
#Check data for null values
healthdf.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df2 = DataFrame(healthdf[['Glucose','Outcome']])
df2.isna().sum()
pregnancy = DataFrame(healthdf[['Pregnancies','Outcome']])
thickness = DataFrame(healthdf[['SkinThickness','Outcome']])

# %%
sns.histplot(x='Glucose',data=df2,kde=True,hue=df2['Outcome'])
print('Correlation between Diabetes outcome and Blood Glucose level')
print('Correlation Coefficient = 0.47')
# Out:
# Correlation between Diabetes outcome and Blood Glucose level
# Correlation Coefficient = 0.47

# %%
sns.histplot(x='Pregnancies',data=pregnancy,kde=True,hue=pregnancy['Outcome'])
print('Correlation between Diabetes Outcome and Past Pregnancies')
# Out:
# Correlation between Diabetes Outcome and Past Pregnancies

# %%
sns.histplot(x='Age',data=healthdf,kde=True,hue=healthdf['Outcome'])
print('Correlation between Diabetes Outcome and Age')
# Out:
# Correlation between Diabetes Outcome and Age

# %%
import statsmodels.formula.api as smf
model = smf.ols('Outcome ~ Glucose', healthdf).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                Outcome   R-squared:                       0.218
# Model:                            OLS   Adj. R-squared:                  0.217
# Method:                 Least Squares   F-statistic:                     213.2
# Date:                Thu, 03 Nov 2022   Prob (F-statistic):           8.94e-43
# Time:                        14:45:21   Log-Likelihood:                -426.39
# No. Observations:                 768   AIC:                             856.8
# Df Residuals:                     766   BIC:                             866.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4925      0.060     -8.262      0.000      -0.610      -0.375
# ...

# %%
#Understand the correlation between different columns in the dataset for possible statistical significance
#Through Correlation coefficient
import scipy.stats as st
sns.heatmap(healthdf.corr(), annot = True)
# Out:
# <AxesSubplot: >
